# %%
import pandas as pd

try:
    with open('estrutura_grafos.txt', 'r') as file:
        texto_txt = file.read()
        
    print("\nConteúdo do arquivo .txt:\n")
    print(texto_txt)

except FileNotFoundError:
    print("\nO arquivo .txt não foi encontrado.")
# Out:
# Conteúdo do arquivo .txt:
#
#
#
# Estrutura do Grafo - BHW1.dat
#
#
# Vertices (id, demanda, s.custo):
# id,demanda,s.custo
# 4,1,1
# 3,1,1
# 10,1,1
# 2,1,1
# 11,1,1
# 12,1,1
# 7,1,1
#
# Arestas (Tipo, Origem, Destino, Custo, Demanda, S.Custo):
# Tipo,Origem,Destino,Custo,Demanda,S.Custo
# Aresta,2,3,18,1,19
# Aresta,2,4,9,1,10
# Aresta,2,9,2,1,3
# Aresta,5,6,7,1,8
# Aresta,5,11,20,1,21
# Aresta,5,12,11,1,12
# Aresta,7,8,8,1,9
# Aresta,7,12,18,1,19
# Aresta,8,11,10,1,11
# Aresta,9,10,16,1,17
# Aresta,10,11,12,1,13
#
# Arcos (Tipo, Origem, Destino, Custo, Demanda, S.Custo):
# Tipo,Origem,Destino,Custo,Demanda,S.Custo
# Arco,1,2,13,1,14
# Arco,1,4,17,1,18
# Arco,1,7,19,1,20
# Arco,1,10,19,1,20
# Arco,1,12,4,1,5
# Arco,3,4,20,1,21
# Arco,5,3,5,1,6
# Arco,7,6,4,1,5
# Arco,12,6,3,1,4
# Arco,8,10,3,1,4
# Arco,9,11,14,1,15
# Arco,2,1,13,0,0
# Arco,4,1,17,0,0
# Arco,7,1,19,0,0
# Arco,10,1,19,0,0
# Arco,12,1,4,0,0
# Arco,4,3,20,0,0
# Arco,3,5,5,0,0
# Arco,6,7,4,0,0
# Arco,6,12,3,0,0
# ...
